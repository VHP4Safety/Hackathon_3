# %%
# !pip install -U langchain langchain-community langgraph langchain-openai
# Out:
# Requirement already satisfied: langchain in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (0.2.14)
# Requirement already satisfied: langchain-community in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (0.2.12)
# Requirement already satisfied: langgraph in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (0.2.10)
# Requirement already satisfied: langchain-openai in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (0.1.22)
# Requirement already satisfied: PyYAML>=5.3 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (1.4.50)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.32 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (0.2.33)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (0.1.100)
# Requirement already satisfied: numpy<2,>=1 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (1.26.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain-community) (0.5.14)
# Requirement already satisfied: langgraph-checkpoint<2.0.0,>=1.0.2 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langgraph) (1.0.3)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain-openai) (1.42.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.25.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.5.0)
# Requirement already satisfied: sniffio in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: regex>=2022.1.18 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.7.24)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain) (2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ivodjidrovski/langchain_env/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %% [markdown]
# # BridgeDB API Integration with LangChain Agent
#
# This notebook demonstrates the integration of the BridgeDB API with a LangChain-powered AI agent for biological identifier mapping.
#
# ## Table of Contents
# 1. Setup and Imports
# 2. BridgeDB API Wrapper
# 3. Custom LangChain Tool
# 4. AI Agent Configuration
# 5. Testing the Agent
# 6. Additional Utility Functions
# 7. Direct API Calls
#
# ## 1. Setup and Imports
#
# First, let's set up our environment and import the necessary libraries.

# %%
# Import statements
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from langchain_community.tools import BaseTool
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from langgraph.checkpoint.memory import MemorySaver

# Load environment variables
load_dotenv()

# Set OpenAI API Key
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OpenAI API Key is not set. Please check your .env file.")

os.environ["OPENAI_API_KEY"] = api_key

# %% [markdown]
# ## 2. BridgeDB API Wrapper
#
# We'll create a wrapper class for the BridgeDB API to handle identifier mapping requests.

# %%
# BridgeDbAPI Class
# This class encapsulates the functionality to interact with the BridgeDb web service:
# - `BASE_URL`: The base URL for the BridgeDb API
# - `map_identifier`: A method to map identifiers between different biological databases

class BridgeDbAPI:
    BASE_URL = "https://webservice.bridgedb.org"

    @staticmethod
    def map_identifier(species, source_ds, identifier):
        url = f"{BridgeDbAPI.BASE_URL}/{species}/xrefs/{source_ds}/{identifier}"
        response = requests.get(url)
        if response.status_code == 200:
            return [line.split('\t') for line in response.text.strip().split('\n')]
        else:
            return f"Error: {response.status_code} - {response.reason}"

    @staticmethod
    def get_supported_data_sources(species):
        url = f"{BridgeDbAPI.BASE_URL}/{species}/sourceDataSources"
        response = requests.get(url)
        if response.status_code == 200:
            return response.text.strip().split('\n')
        else:
            return f"Error: {response.status_code} - {response.reason}"

# %%
"""# IdentifierMappingTool Class
This class extends BaseTool to create a custom tool for Langchain:
- It parses queries and uses BridgeDBAPI to perform identifier mapping
- The `_run` method handles synchronous operations
- The `_arun` method is a placeholder for asynchronous operations (not implemented)

The `tools` list is created with an instance of this tool."""


class IdentifierMappingTool(BaseTool):
    name = "identifier_mapping"
    description = "Useful for mapping identifiers between different biological databases"

    def _run(self, query: str) -> str:
        # Parse the query; now expecting only three parts: species, source_ds, identifier
        parts = query.split(",")
        if len(parts) != 3:
            return "Error: Query should be in the format 'species, source_ds, identifier'"
        species, source_ds, identifier = [p.strip() for p in parts]
        
        # Attempt to map identifiers and handle potential errors
        try:
            result = BridgeDbAPI().map_identifier(species, source_ds, identifier)
            if isinstance(result, list):
                # Formatting the output as a list
                formatted_result = "\n".join([f"- {item}" for item in result])
                return f"Mapped identifiers:\n{formatted_result}"
            else:
                return f"Error: {result}"  # This handles non-list responses like error messages
        except Exception as e:
            return f"Error: {str(e)}"

    def _arun(self, query: str) -> str:
        # Async implementation (not needed for this tool)
        raise NotImplementedError("This tool does not support async")
    
tools = [IdentifierMappingTool()]

# %%
# Test with a different ENSG identifier (e.g., BRCA2)
tool = IdentifierMappingTool()
print(tool._run("Homo sapiens, Ensembl, ENSG00000139618"))
# Out:
# Mapped identifiers:
# - ['214727_PM_at', 'Affy']
# - ['GO:0006978', 'GeneOntology']
# - ['GO:0072089', 'GeneOntology']
# - ['GO:1990426', 'GeneOntology']
# - ['11740416_at', 'Affy']
# - ['GO:0006974', 'GeneOntology']
# - ['uc058wfw.1', 'UCSC Genome Browser']
# - ['GO:0043009', 'GeneOntology']
# - ['BRCA2', 'HGNC']
# - ['A0A590UJ24', 'Uniprot-TrEMBL']
# - ['1N0W', 'PDB']
# - ['GO:0032465', 'GeneOntology']
# - ['3484692', 'Affy']
# - ['GO:0001833', 'GeneOntology']
# - ['GO:0045893', 'GeneOntology']
# - ['3484695', 'Affy']
# - ['3484694', 'Affy']
# - ['GO:0001556', 'GeneOntology']
# - ['3484697', 'Affy']
# - ['GO:0005515', 'GeneOntology']
# - ['3484696', 'Affy']
# - ['3484699', 'Affy']
# - ['3484698', 'Affy']
# - ['208368_PM_s_at', 'Affy']
# - ['GO:0005634', 'GeneOntology']
# - ['675', 'Entrez Gene']
# - ['GO:0006289', 'GeneOntology']
# - ['GO:0003697', 'GeneOntology']
# - ['GO:0045931', 'GeneOntology']
# - ['GO:2000001', 'GeneOntology']
# - ['7968484', 'Affy']
# - ['GO:0007420', 'GeneOntology']
# - ['GO:0008630', 'GeneOntology']
# - ['GO:0032991', 'GeneOntology']
# - ['675', 'WikiGenes']
# - ['GO:0007141', 'GeneOntology']
# - ['214727_at', 'Affy']
# - ['7LDG', 'PDB']
# - ['3484691', 'Affy']
# - ['3484690', 'Affy']
# - ['GO:0033600', 'GeneOntology']
# - ['P51587', 'Uniprot-TrEMBL']
# - ['3484660', 'Affy']
# - ['GO:0070200', 'GeneOntology']
# - ['3484662', 'Affy']
# - ['3484664', 'Affy']
# - ['3484663', 'Affy']
# - ['3484666', 'Affy']
# - ['3484668', 'Affy']
# - ['3484701', 'Affy']
# - ['3484667', 'Affy']
# - ['uc058wfv.2', 'UCSC Genome Browser']
# - ['3484703', 'Affy']
# - ['3484669', 'Affy']
# - ['Hs.34012.1.S1_3p_at', 'Affy']
# - ['3484705', 'Affy']
# - ['GO:0006310', 'GeneOntology']
# - ['3484707', 'Affy']
# - ['A_14_P109686', 'Agilent']
# - ['uc288ccz.1', 'UCSC Genome Browser']
# - ['GO:0008585', 'GeneOntology']
# - ['GO:0006281', 'GeneOntology']
# - ['GO:0035518', 'GeneOntology']
# - ['HMNXSV003047584', 'Agilent']
# - ['3484671', 'Affy']
# - ['3484670', 'Affy']
# - ['GO:0000722', 'GeneOntology']
# - ['3484673', 'Affy']
# - ['3484672', 'Affy']
# - ['0005670053', 'Illumina']
# - ['3484675', 'Affy']
# - ['GO:0005856', 'GeneOntology']
# - ['HGNC:1101', 'HGNC Accession number']
# - ['3484674', 'Affy']
# - ['3484677', 'Affy']
# - ['GO:0005737', 'GeneOntology']
# - ['3484676', 'Affy']
# - ['GO:0000724', 'GeneOntology']
# - ['3484678', 'Affy']
# - ['A_23_P99452', 'Agilent']
# - ['GO:0043015', 'GeneOntology']
# - ['GO:1990391', 'GeneOntology']
# - ['GO:0003677', 'GeneOntology']
# - ['GO:0005694', 'GeneOntology']
# - ['A0A590UJI7', 'Uniprot-TrEMBL']
# - ['GO:0006302', 'GeneOntology']
# - ['3484708', 'Affy']
# - ['A0A7P0T9D7', 'Uniprot-TrEMBL']
# - ['GO:0051276', 'GeneOntology']
# - ['A_14_P131744', 'Agilent']
# - ['600185', 'OMIM']
# - ['GO:0071425', 'GeneOntology']
# - ['1990_g_at', 'Affy']
# - ['GO:0010484', 'GeneOntology']
# - ['GO:0010485', 'GeneOntology']
# - ['ILMN_1677794', 'Illumina']
# - ['X95152_rna1_at', 'Affy']
# - ['A_14_P100214', 'Agilent']
# - ['Q17853272', 'Wikidata']
# - ['3484642', 'Affy']
# - ['NP_000050', 'RefSeq']
# - ['3484644', 'Affy']
# - ['GO:0090398', 'GeneOntology']
# - ['3484643', 'Affy']
# - ['7BDX', 'PDB']
# - ['3484646', 'Affy']
# - ['GO:0000152', 'GeneOntology']
# - ['3484645', 'Affy']
# - ['3484648', 'Affy']
# - ['GO:0043966', 'GeneOntology']
# - ['H0YE37', 'Uniprot-TrEMBL']
# - ['3484647', 'Affy']
# - ['GO:0043967', 'GeneOntology']
# - ['uc058wfu.1', 'UCSC Genome Browser']
# - ['3484649', 'Affy']
# - ['uc058wfy.1', 'UCSC Genome Browser']
# - ['NM_000059', 'RefSeq']
# - ['GO:0008283', 'GeneOntology']
# - ['uc289bmu.1', 'UCSC Genome Browser']
# - ['GO:0033593', 'GeneOntology']
# - ['GO:0071479', 'GeneOntology']
# - ['GO:0050896', 'GeneOntology']
# - ['GO:0051865', 'GeneOntology']
# - ['3484651', 'Affy']
# - ['3484650', 'Affy']
# - ['208368_3p_s_at', 'Affy']
# - ['3484653', 'Affy']
# - ['uc288dpn.1', 'UCSC Genome Browser']
# - ['3484652', 'Affy']
# - ['3484655', 'Affy']
# - ['3484654', 'Affy']
# - ['3484657', 'Affy']
# - ['3484659', 'Affy']
# - ['16773840', 'Affy']
# - ['3484658', 'Affy']
# - ['GO:0000781', 'GeneOntology']
# - ['GO:0030097', 'GeneOntology']
# - ['GO:0010225', 'GeneOntology']
# - ['GO:0051298', 'GeneOntology']
# - ['g4502450_3p_a_at', 'Affy']
# - ['GO:0005829', 'GeneOntology']
# - ['GO:0048478', 'GeneOntology']
# - ['GO:0042771', 'GeneOntology']
# - ['uc058wfx.1', 'UCSC Genome Browser']
# - ['uc058wft.2', 'UCSC Genome Browser']
# - ['GO:0006355', 'GeneOntology']
# - ['GO:0007049', 'GeneOntology']
# - ['GO:0008022', 'GeneOntology']
# - ['GO:0030141', 'GeneOntology']
# - ['6GY2', 'PDB']
# - ['A0A590UJU6', 'Uniprot-TrEMBL']
# - ['GO:0010332', 'GeneOntology']
# - ['1503_at', 'Affy']
# - ['uc001uub.3', 'UCSC Genome Browser']
# - ['GO:0005813', 'GeneOntology']
# - ['GO:0000800', 'GeneOntology']
# - ['GO:0005815', 'GeneOntology']
# - ['GO:0005654', 'GeneOntology']
# - ['GO:0002020', 'GeneOntology']
# - ['H0YD86', 'Uniprot-TrEMBL']
# - ['ENSG00000139618', 'Ensembl']
# - ['GO:0042802', 'GeneOntology']
# - ['A0A7P0TAP7', 'Uniprot-TrEMBL']
# - ['TC13000111.hg', 'Affy']
# - ['1989_at', 'Affy']
# - ['GO:0007283', 'GeneOntology']
# - ['3EU7', 'PDB']
# - ['GO:0010165', 'GeneOntology']
# - ['6HQU', 'PDB']
# - ['208368_s_at', 'Affy']

# %% [markdown]
# ## 3. Custom LangChain Tool
#
# Now, let's create a custom LangChain tool that uses our BridgeDbAPI wrapper.

# %%
import requests

class IdentifierMappingTool(BaseTool):
    name = "identifier_mapping"
    description = """Map identifiers between different biological databases. 
    Input can be in the following formats:
    1. 'species, source_ds, identifier' (e.g., 'Homo sapiens, Ensembl, ENSG00000139618')
    2. 'source_ds, identifier' (e.g., 'Cpc, 2478')
    3. Just the identifier or gene/chemical name (e.g., 'ENSG00000139618' or 'BRCA2' or 'Busulfan')"""

    def _run(self, query: str) -> str:
        parts = [p.strip() for p in query.split(",")]
        
        if len(parts) == 1:
            return self._flexible_mapping(parts[0])
        elif len(parts) == 2:
            source_ds, identifier = parts
            return self._map_identifier("Human", source_ds, identifier)
        elif len(parts) == 3:
            species, source_ds, identifier = parts
            return self._map_identifier(species, source_ds, identifier)
        else:
            return "Error: Invalid query format."

    def _flexible_mapping(self, query):
        # Try mapping as Ensembl gene ID
        result = self._map_identifier("Human", "En", query)
        if "Error" not in result:
            return result

        # Try mapping as HGNC ID
        if query.startswith("HGNC:"):
            result = self._map_identifier("Human", "H", query)
            if "Error" not in result:
                return result

        # Try mapping as gene symbol
        result = self._map_identifier("Human", "H", query)
        if "Error" not in result:
            return result

        # Try mapping as PubChem compound ID
        result = self._map_identifier("Human", "Cpc", query)
        if "Error" not in result:
            return result

        # If it fails, assume it's a chemical name and try to find its PubChem ID
        pubchem_id = self._get_pubchem_id(query)
        if pubchem_id:
            return self._map_identifier("Human", "Cpc", pubchem_id)
        
        return f"Error: Unable to map identifier or find compound: {query}"

    def _map_identifier(self, species, source_ds, identifier):
        url = f"https://bridgedb.cloud.vhp4safety.nl/{species}/xrefs/{source_ds}/{identifier}"
        response = requests.get(url)
        if response.status_code == 200:
            mappings = [line.split('\t') for line in response.text.strip().split('\n')]
            if mappings:
                formatted_result = "\n".join([f"- {item[0]}\t{item[1]}" for item in mappings])
                return f"Mapped identifiers for {identifier} from {source_ds}:\n{formatted_result}"
            else:
                return f"No mappings found for {identifier} from {source_ds}"
        else:
            return f"Error: Failed to retrieve mappings. Status code: {response.status_code}"

    def _get_pubchem_id(self, chemical_name):
        url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{chemical_name}/cids/TXT"
        response = requests.get(url)
        if response.status_code == 200:
            return response.text.strip()
        return None

    async def _arun(self, query: str) -> str:
        return self._run(query)

# %% [markdown]
# ## 4. AI Agent Configuration
#
# Let's set up our AI agent using the custom tool we created.

# %%
from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage

def create_bridgedb_agent():
    model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
    tools = [IdentifierMappingTool()]
    memory = MemorySaver()
    agent_executor = create_react_agent(model, tools, checkpointer=memory)
    return agent_executor

bridgedb_agent = create_bridgedb_agent()

def run_agent_query(query):
    config = {"configurable": {"thread_id": "bridgedb_conversation"}}
    
    print(f"Query: {query}\n")
    for chunk in bridgedb_agent.stream(
        {"messages": [HumanMessage(content=query)]},
        config
    ):
        if 'agent' in chunk and 'messages' in chunk['agent']:
            for message in chunk['agent']['messages']:
                if hasattr(message, 'content') and message.content:
                    print(message.content)
        print("----")
    print("\n")

# Test queries

run_agent_query("What are the mappings for the compound with PubChem ID 2478?")
run_agent_query("Find mappings for Busulfan")
run_agent_query("Find mappings for Aflatoxin B1")
# Out:
# Query: What are the mappings for the compound with PubChem ID 2478?
#
# ----
# ----
# The compound with PubChem ID 2478 has the following mappings across different databases:
#
# - **ChemSpider**: 2384
# - **EPA CompTox**: DTXSID3020910
# - **HMDB**: HMDB15143
# - **ChEBI**: 28901
# - **PubChem**: 2478
# - **Wikidata**: Q348922
# - **CAS**: 55-98-1
# - **DrugBank**: DB01008
# - **ChEBI**: CHEBI:28901
# - **Guide to Pharmacology**: 7136
# - **KEGG Drug**: D00248
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
# - **ChEMBL compound**: CHEMBL820
# - **KEGG Compound**: C06862
#
# These identifiers can be used to find more information about the compound in various biological and chemical databases.
# ----
#
#
# Query: Find mappings for Busulfan
#
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# The compound Busulfan has the following mappings across different databases:
#
# - **ChemSpider**: 2384
# - **EPA CompTox**: DTXSID3020910
# - **HMDB**: HMDB15143
# - **ChEBI**: 28901
# - **PubChem**: 2478
# - **Wikidata**: Q348922
# - **CAS**: 55-98-1
# - **DrugBank**: DB01008
# - **ChEBI**: CHEBI:28901
# - **Guide to Pharmacology**: 7136
# - **KEGG Drug**: D00248
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
# - **ChEMBL compound**: CHEMBL820
# - **KEGG Compound**: C06862
#
# These identifiers can be used to find more information about Busulfan in various biological and chemical databases.
# ----
#
#
# Query: Find mappings for Aflatoxin B1
#
# ----
# ----
# The compound Aflatoxin B1 has the following mappings across different databases:
#
# - **KNApSAcK**: C00000546
# - **ChEBI**: CHEBI:2504
# - **KEGG Compound**: C06800
# - **EPA CompTox**: DTXSID00873175
# - **PubChem**: 186907
# - **InChIKey**: OQIQSTLJSLGHID-WNWIJWBNSA-N
# - **ChEMBL compound**: CHEMBL1697694
# - **EPA CompTox**: DTXSID9020035
# - **CAS**: 1162-65-8
# - **ChemSpider**: 162470
# - **Wikidata**: Q4689278
# - **HMDB**: HMDB0006552
# - **ChEBI**: 2504
# - **HMDB**: HMDB06552
#
# These identifiers can be used to find more information about Aflatoxin B1 in various biological and chemical databases.
# ----

# %%
def create_bridgedb_agent():
    model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
    tools = [IdentifierMappingTool()]
    memory = MemorySaver()
    agent_executor = create_react_agent(model, tools, checkpointer=memory)
    return agent_executor

bridgedb_agent = create_bridgedb_agent()

# Test queries
run_agent_query("Map the gene ENSG00000139618 from Ensembl to other databases")
run_agent_query("What are the mappings for the compound with PubChem ID 2478?")
run_agent_query("Find mappings for Busulfan")
# Out:
# Query: Map the gene ENSG00000139618 from Ensembl to other databases
#
# ----
# ----
# ----
# ----
# The gene **ENSG00000139618** from Ensembl has been mapped to various identifiers in different biological databases. Here are some of the mappings:
#
# - **HGNC**: BRCA2
# - **Entrez Gene**: 675
# - **UniProt-TrEMBL**: A0A590UJ24, P51587, A0A590UJI7, A0A7P0T9D7, H0YE37, A0A590UJU6, H0YD86, A0A7P0TAP7
# - **RefSeq**: NP_000050, NM_000059
# - **Gene Ontology (GO)**: Multiple entries including GO:0006978, GO:0072089, GO:1990426, etc.
# - **Affymetrix**: 214727_PM_at, 11740416_at, 3484692, etc.
# - **UCSC Genome Browser**: uc058wfw.1, uc058wfv.2, uc288ccz.1, etc.
# - **PDB**: 1N0W, 7LDG, 6GY2, 3EU7, 6HQU
# - **OMIM**: 600185
# - **Wikidata**: Q17853272
#
# This gene is associated with various biological functions and pathways, as indicated by the numerous Gene Ontology terms. If you need more specific information or additional mappings, feel free to ask!
# ----
#
#
# Query: What are the mappings for the compound with PubChem ID 2478?
#
# ----
# ----
# The compound with **PubChem ID 2478** has been mapped to various identifiers in different databases. Here are the mappings:
#
# - **PubChem**: 2478
# - **ChemSpider**: 2384
# - **EPA CompTox**: DTXSID3020910
# - **HMDB**: HMDB15143, HMDB0015143
# - **ChEBI**: 28901, CHEBI:28901
# - **Wikidata**: Q348922
# - **CAS**: 55-98-1
# - **DrugBank**: DB01008
# - **Guide to Pharmacology**: 7136
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChEMBL**: CHEMBL820
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
#
# If you need further information or additional mappings, feel free to ask!
# ----
#
#
# Query: Find mappings for Busulfan
#
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# The compound **Busulfan** has been mapped to various identifiers in different databases. Here are the mappings:
#
# - **PubChem**: 2478
# - **ChemSpider**: 2384
# - **EPA CompTox**: DTXSID3020910
# - **HMDB**: HMDB15143, HMDB0015143
# - **ChEBI**: 28901, CHEBI:28901
# - **Wikidata**: Q348922
# - **CAS**: 55-98-1
# - **DrugBank**: DB01008
# - **Guide to Pharmacology**: 7136
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChEMBL**: CHEMBL820
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
#
# If you need more information or further assistance, feel free to ask!
# ----

# %% [markdown]
# ## 5. Testing the Agent
#
# Now let's test our agent with some example queries.

# %%
def create_bridgedb_agent():
    model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
    tools = [IdentifierMappingTool()]
    memory = MemorySaver()
    agent_executor = create_react_agent(model, tools, checkpointer=memory)
    return agent_executor

bridgedb_agent = create_bridgedb_agent()

# Test queries
print("Test 1: Gene Identifier Queries\n")
run_agent_query("Map the gene ENSG00000130203 from Ensembl to other databases")
run_agent_query("What are the mappings for the HGNC gene ID HGNC:1101?")
run_agent_query("Find identifiers for the human gene BRCA2")
# Out:
# Test 1: Gene Identifier Queries
#
# Query: Map the gene ENSG00000130203 from Ensembl to other databases
#
# ----
# ----
# The gene **ENSG00000130203** from Ensembl has been mapped to various identifiers in different biological databases. Here are some of the mappings:
#
# ### Gene Ontology (GO)
# - GO:0043083
# - GO:0016020
# - GO:0043524
# - GO:0042311
# - GO:0046911
# - GO:0034364
# - GO:0034365
# - GO:0034362
# - GO:0043407
# - GO:0034363
# - GO:0120009
# - GO:0050728
# - GO:0071682
# - GO:0034380
# - GO:1902952
# - GO:0090181
# - GO:0034375
# - GO:0034374
# - GO:0062023
# - GO:0034372
# - GO:0046907
# - GO:0097006
# - GO:0097487
# - GO:0044877
# - GO:0001540
# - GO:0005102
# - GO:1902995
# - GO:0034384
# - GO:0034382
# - GO:0055088
# - GO:1902991
# - GO:0055089
# - GO:0070328
# - GO:0120020
# - GO:0051044
# - GO:0050750
# - GO:0070326
# - GO:0019068
# - GO:0048662
# - GO:0097113
# - GO:0097114
# - GO:0043537
# - GO:0005576
# - GO:0006979
# - GO:0005769
# - GO:0042159
# - GO:0005886
# - GO:0042158
# - GO:0042157
# - GO:0071830
# - GO:0007271
# - GO:1900272
# - GO:0071813
# - GO:0045893
# - GO:0046983
# - GO:0005515
# - GO:1990777
# - GO:0005634
# - GO:0007263
# - GO:0010544
# - GO:0051651
# - GO:0098869
# - GO:0098978
# - GO:0048156
# - GO:0032805
# - GO:0043025
# - GO:0007010
# - GO:0005198
# - GO:1903561
# - GO:1905860
# - GO:0072562
# - GO:0006898
# - GO:1905920
# - GO:0008289
# - GO:0010596
# - GO:0000302
# - GO:0007616
# - GO:0005319
# - GO:0006641
# - GO:0005794
# - GO:0007186
# - GO:0016209
# - GO:0010467
# - GO:0010468
# - GO:1900223
# - GO:0061771
# - GO:0032438
# - GO:0044794
# - GO:0045088
# - GO:0015909
# - GO:0005788
# - GO:0005783
# - GO:0090090
# - GO:0006874
# - GO:0005543
# - GO:1902430
# - GO:0019934
#
# ### Other Databases
# - **HGNC**: APOE (HGNC:613)
# - **RefSeq**: NP_001289620, NP_001289617, NP_001289618, NM_001302691, NM_001302690, NM_001302688, NM_001302689, NM_000041, NP_000032
# - **UCSC Genome Browser**: uc002pab.5, uc060zuf.1, uc060zue.1, uc060zug.1, uc060zuh.1
# - **Affymetrix**: 203381_PM_s_at, M12529_at, 212884_PM_x_at, 16863115, 348, 203381_s_at, 608_at, 11744068_x_at, 3835890, 3835889, 3835888, 3835887, 3835886, 3835885, 3835884, 3835883, 3835882, 3835881, 3835880
# - **PDB**: 2KNY, 1LE4, 1LE2, 1NFO, 1NFN, 1LPE, 1H7I, 1OEG, 1OEF, 1EA8, 1B68, 2L7B, 6NCO, 6NCN, 6IWB
# - **Entrez Gene**: 348
# - **Wikidata**: Q14890468
# - **Uniprot-TrEMBL**: A0A0S2Z3D5, E7ERP7, H0Y7L5, P02649, E9PEV4
#
# This mapping provides a comprehensive overview of the gene's identifiers across various biological databases.
# ----
#
#
# Query: What are the mappings for the HGNC gene ID HGNC:1101?
#
# ----
# ----
# It seems that there was an issue retrieving the mappings for the HGNC gene ID **HGNC:1101**. This could be due to the identifier not being recognized or available in the databases I queried.
#
# If you have any other identifiers or specific queries related to this gene, please let me know, and I'll be happy to assist!
# ----
#
#
# Query: Find identifiers for the human gene BRCA2
#
# ----
# ----
# The human gene **BRCA2** has been mapped to various identifiers across different biological databases. Here are some of the mappings:
#
# ### Gene Ontology (GO)
# - GO:0006978
# - GO:0072089
# - GO:1990426
# - GO:0006974
# - GO:0043009
# - GO:0032465
# - GO:0001833
# - GO:0045893
# - GO:0001556
# - GO:0005515
# - GO:0005634
# - GO:0006289
# - GO:0003697
# - GO:0045931
# - GO:2000001
# - GO:0007420
# - GO:0008630
# - GO:0032991
# - GO:0007141
# - GO:0033600
# - GO:0070200
# - GO:0008585
# - GO:0006281
# - GO:0035518
# - GO:0000722
# - GO:0005737
# - GO:0000724
# - GO:0043015
# - GO:1990391
# - GO:0003677
# - GO:0005694
# - GO:0006302
# - GO:0051276
# - GO:0071425
# - GO:0010484
# - GO:0010485
# - GO:0000152
# - GO:0043966
# - GO:0043967
# - GO:0008283
# - GO:0033593
# - GO:0071479
# - GO:0050896
# - GO:0051865
# - GO:0000781
# - GO:0030097
# - GO:0010225
# - GO:0051298
# - GO:0005829
# - GO:0048478
# - GO:0042771
# - GO:0006355
# - GO:0007049
# - GO:0008022
# - GO:0030141
#
# ### Other Databases
# - **HGNC**: BRCA2 (HGNC:1101)
# - **RefSeq**: NP_000050, NM_000059
# - **Ensembl**: ENSG00000139618
# - **Uniprot-TrEMBL**: A0A590UJ24, P51587, A0A590UJI7, A0A7P0T9D7, H0YE37, H0YD86, A0A590UJU6, A0A7P0TAP7
# - **Affymetrix**: 214727_PM_at, 11740416_at, 3484692, 3484695, 3484694, 3484697, 3484696, 3484699, 3484698, 208368_PM_s_at, 675, 3484691, 3484690, 3484660, 3484662, 3484664, 3484663, 3484666, 3484668, 3484701, 3484667, 3484703, 3484669, 3484705, 3484707, 3484671, 3484670, 3484673, 3484672, 3484675, 3484674, 3484677, 3484676, 3484678, 3484708, 3484642, 3484644, 3484643, 3484646, 3484645, 3484648, 3484647, 3484649, 3484651, 3484650, 208368_3p_s_at, 3484653, 3484652, 3484655, 3484654, 3484657, 3484659, 16773840, 3484658, 1503_at, 1989_at, TC13000111.hg
# - **PDB**: 1N0W, 7LDG, 3EU7, 6GY2, 6HQU
# - **Entrez Gene**: 675
# - **WikiGenes**: 675
# - **UCSC Genome Browser**: uc058wfw.1, uc058wfv.2, uc288ccz.1, uc058wfu.1, uc058wfy.1, uc289bmu.1, uc288dpn.1, uc058wfx.1, uc058wft.2, uc001uub.3
#
# This mapping provides a comprehensive overview of the BRCA2 gene's identifiers across various biological databases.
# ----

# %%
#2. Compound identifier mappings
print("Test 2: Compound Queries by ID\n")
run_agent_query("What are the mappings for the compound with PubChem ID 2478?")
run_agent_query("Map the ChEBI ID CHEBI:28901 to other databases")
run_agent_query("Find identifiers for the DrugBank entry DB01008")
# Out:
# Test 2: Compound Queries by ID
#
# Query: What are the mappings for the compound with PubChem ID 2478?
#
# ----
# ----
# The compound with **PubChem ID 2478** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### Compound Identifiers
# - **PubChem**: 2478
# - **CAS**: 55-98-1
# - **ChEBI**: 28901
# - **HMDB**: HMDB15143
# - **DrugBank**: DB01008
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChemSpider**: 2384
# - **ChEMBL**: CHEMBL820
# - **EPA CompTox**: DTXSID3020910
# - **Guide to Pharmacology**: 7136
# - **Wikidata**: Q348922
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
#
# This mapping provides a comprehensive overview of the compound's identifiers across various biological and chemical databases.
# ----
#
#
# Query: Map the ChEBI ID CHEBI:28901 to other databases
#
# ----
# ----
# The ChEBI ID **CHEBI:28901** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### Compound Identifiers
# - **ChEBI**: CHEBI:28901
# - **PubChem**: 2478
# - **CAS**: 55-98-1
# - **HMDB**: HMDB15143
# - **DrugBank**: DB01008
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChemSpider**: 2384
# - **ChEMBL**: CHEMBL820
# - **EPA CompTox**: DTXSID3020910
# - **Guide to Pharmacology**: 7136
# - **Wikidata**: Q348922
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
#
# This mapping provides a comprehensive overview of the ChEBI ID's identifiers across various biological and chemical databases.
# ----
#
#
# Query: Find identifiers for the DrugBank entry DB01008
#
# ----
# ----
# The DrugBank entry **DB01008** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### DrugBank Identifiers
# - **DrugBank**: DB01008
# - **PubChem**: 2478
# - **ChEBI**: CHEBI:28901
# - **CAS**: 55-98-1
# - **HMDB**: HMDB15143
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChemSpider**: 2384
# - **ChEMBL**: CHEMBL820
# - **EPA CompTox**: DTXSID3020910
# - **Guide to Pharmacology**: 7136
# - **Wikidata**: Q348922
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
#
# This mapping provides a comprehensive overview of the DrugBank entry's identifiers across various biological and chemical databases.
# ----

# %%
#3. Chemical name to identifier mappings
print("Test 3: Compound Queries by Name\n")
run_agent_query("Find mappings for Busulfan")
run_agent_query("What are the identifiers for Aflatoxin B1?")
run_agent_query("Map the drug Ibuprofen to different databases")
# Out:
# Test 3: Compound Queries by Name
#
# Query: Find mappings for Busulfan
#
# ----
# ----
# The compound **Busulfan** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### Busulfan Identifiers
# - **PubChem**: 2478
# - **CAS**: 55-98-1
# - **ChEBI**: CHEBI:28901
# - **HMDB**: HMDB15143
# - **DrugBank**: DB01008
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChemSpider**: 2384
# - **ChEMBL**: CHEMBL820
# - **EPA CompTox**: DTXSID3020910
# - **Guide to Pharmacology**: 7136
# - **Wikidata**: Q348922
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
#
# This mapping provides a comprehensive overview of Busulfan's identifiers across various biological and chemical databases.
# ----
#
#
# Query: What are the identifiers for Aflatoxin B1?
#
# ----
# ----
# The compound **Aflatoxin B1** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### Aflatoxin B1 Identifiers
# - **PubChem**: 186907
# - **CAS**: 1162-65-8
# - **ChEBI**: CHEBI:2504
# - **KEGG Compound**: C06800
# - **ChemSpider**: 162470
# - **ChEMBL**: CHEMBL1697694
# - **EPA CompTox**: DTXSID00873175
# - **EPA CompTox**: DTXSID9020035
# - **KNApSAcK**: C00000546
# - **Wikidata**: Q4689278
# - **HMDB**: HMDB0006552
# - **HMDB**: HMDB06552
# - **InChIKey**: OQIQSTLJSLGHID-WNWIJWBNSA-N
#
# This mapping provides a comprehensive overview of Aflatoxin B1's identifiers across various biological and chemical databases.
# ----
#
#
# Query: Map the drug Ibuprofen to different databases
#
# ----
# ----
# The drug **Ibuprofen** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### Ibuprofen Identifiers
# - **PubChem**: 3672
# - **DrugBank**: DB01050
# - **CAS**: 15687-27-1
# - **ChEBI**: CHEBI:5855
# - **HMDB**: HMDB01925
# - **KEGG Compound**: C01588
# - **KEGG Drug**: D00126
# - **ChemSpider**: 3544
# - **Wikidata**: Q186969
# - **EPA CompTox**: DTXSID5020732
# - **InChIKey**: HEFNNWSXXWATRW-UHFFFAOYSA-N
# - **Guide to Pharmacology**: 2713
# - **ChEMBL**: CHEMBL521
#
# This mapping provides a comprehensive overview of Ibuprofen's identifiers across various biological and chemical databases.
# ----

# %%
#4. More complex queries that require multiple steps=
print("Test 4: Edge Cases and Complex Queries\n")
run_agent_query("What's the HGNC symbol for ENSG00000139618?")
run_agent_query("Compare the identifiers for Busulfan and Ibuprofen")
run_agent_query("Find the PubChem ID for aspirin and then map it to other databases")
run_agent_query("Is there a connection between the gene BRCA2 and any known drugs?")
# Out:
# Test 4: Edge Cases and Complex Queries
#
# Query: What's the HGNC symbol for ENSG00000139618?
#
# ----
# ----
# The HGNC symbol for the Ensembl gene ID **ENSG00000139618** is **BRCA2**.
# ----
#
#
# Query: Compare the identifiers for Busulfan and Ibuprofen
#
# ----
# ----
# Here is a comparison of the identifiers for **Busulfan** and **Ibuprofen** across various databases:
#
# ### Busulfan Identifiers
# - **PubChem**: 2478
# - **CAS**: 55-98-1
# - **ChEBI**: CHEBI:28901
# - **HMDB**: HMDB15143
# - **DrugBank**: DB01008
# - **KEGG Drug**: D00248
# - **KEGG Compound**: C06862
# - **ChemSpider**: 2384
# - **ChEMBL**: CHEMBL820
# - **EPA CompTox**: DTXSID3020910
# - **Wikidata**: Q348922
# - **InChIKey**: COVZYZSDYWQREU-UHFFFAOYSA-N
# - **HMDB**: HMDB0015143
# - **Guide to Pharmacology**: 7136
#
# ### Ibuprofen Identifiers
# - **PubChem**: 3672
# - **CAS**: 15687-27-1
# - **ChEBI**: CHEBI:5855
# - **HMDB**: HMDB01925
# - **DrugBank**: DB01050
# - **KEGG Drug**: D00126
# - **KEGG Compound**: C01588
# - **ChemSpider**: 3544
# - **ChEMBL**: CHEMBL521
# - **EPA CompTox**: DTXSID5020732
# - **Wikidata**: Q186969
# - **InChIKey**: HEFNNWSXXWATRW-UHFFFAOYSA-N
# - **Guide to Pharmacology**: 2713
#
# ### Summary of Differences
# - **PubChem IDs**: Busulfan (2478) vs. Ibuprofen (3672)
# - **CAS Numbers**: Busulfan (55-98-1) vs. Ibuprofen (15687-27-1)
# - **ChEBI IDs**: Busulfan (CHEBI:28901) vs. Ibuprofen (CHEBI:5855)
# - **DrugBank IDs**: Busulfan (DB01008) vs. Ibuprofen (DB01050)
# - **KEGG Drug IDs**: Busulfan (D00248) vs. Ibuprofen (D00126)
# - **ChemSpider IDs**: Busulfan (2384) vs. Ibuprofen (3544)
# - **ChEMBL IDs**: Busulfan (CHEMBL820) vs. Ibuprofen (CHEMBL521)
#
# Both compounds have identifiers in common across several databases, but they also have unique identifiers that distinguish them in various contexts.
# ----
#
#
# Query: Find the PubChem ID for aspirin and then map it to other databases
#
# ----
# ----
# The **PubChem ID** for **Aspirin** is **2244**. Here are the mappings for Aspirin to other databases:
#
# ### Aspirin Identifiers
# - **PubChem**: 2244
# - **CAS**: 50-78-2
# - **ChEBI**: CHEBI:15365
# - **HMDB**: HMDB01879
# - **DrugBank**: DB00945
# - **KEGG Compound**: C01405
# - **KEGG Drug**: D00109
# - **ChemSpider**: 2157
# - **ChEMBL**: CHEMBL25
# - **EPA CompTox**: DTXSID5020108
# - **Wikidata**: Q18216
# - **InChIKey**: BSYNRYMUTXBXSQ-UHFFFAOYSA-N
# - **Guide to Pharmacology**: 4139
#
# This mapping provides a comprehensive overview of Aspirin's identifiers across various biological and chemical databases.
# ----
#
#
# Query: Is there a connection between the gene BRCA2 and any known drugs?
#
# ----
# ----
# Yes, there is a connection between the gene **BRCA2** and known drugs, particularly in the context of cancer treatment. The BRCA2 gene is involved in the repair of DNA breaks, and mutations in this gene are associated with an increased risk of breast and ovarian cancers.
#
# ### Known Drugs Related to BRCA2
# 1. **PARP Inhibitors**:
#    - **Olaparib (Lynparza)**: Used for treating BRCA-mutated breast and ovarian cancers.
#    - **Rucaparib (Rubraca)**: Another PARP inhibitor for BRCA-mutated cancers.
#    - **Niraparib (Zejula)**: Also used in the treatment of BRCA-related cancers.
#
# 2. **Chemotherapy Agents**:
#    - Certain chemotherapy drugs may be more effective in patients with BRCA2 mutations due to the impaired DNA repair mechanisms.
#
# 3. **Targeted Therapies**:
#    - Drugs that target specific pathways affected by BRCA2 mutations are being researched and developed.
#
# ### Summary
# The connection between BRCA2 and drugs primarily revolves around the treatment of cancers associated with BRCA2 mutations, particularly through the use of PARP inhibitors and other targeted therapies. These drugs exploit the vulnerabilities in cancer cells that arise from defective DNA repair mechanisms due to BRCA2 mutations.
# ----

# %%
#Edge cases and potentially problematic queries
print("Test 5: Incorrect or Ambiguous Queries\n")
run_agent_query("Map the identifier XYZ123")
run_agent_query("What are the mappings for water?")
run_agent_query("Find identifiers for COVID-19")
run_agent_query("Map ENSG00000139618 to PubChem")
# Out:
# Test 5: Incorrect or Ambiguous Queries
#
# Query: Map the identifier XYZ123
#
# ----
# ----
# It seems that the identifier **XYZ123** could not be mapped to any known entries in the biological or chemical databases. This may be due to it not being a recognized identifier or it may not correspond to any existing compound, gene, or protein.
#
# If you have another identifier or a specific query in mind, please let me know, and I'll be happy to assist!
# ----
#
#
# Query: What are the mappings for water?
#
# ----
# ----
# The compound **Water** has been mapped to various identifiers across different databases. Here are the mappings:
#
# ### Water Identifiers
# - **PubChem**: 962
# - **CAS**: 7732-18-5
# - **ChEBI**: CHEBI:15377
# - **HMDB**: HMDB0002111
# - **DrugBank**: DB09145
# - **KEGG Drug**: D00001
# - **KEGG Compound**: C00001
# - **ChemSpider**: 937
# - **ChEMBL**: CHEMBL1098659
# - **EPA CompTox**: DTXSID6026296
# - **Wikidata**: Q283
# - **InChIKey**: XLYOFNOQVPJJNP-UHFFFAOYSA-N
# - **HMDB**: HMDB02111
#
# This mapping provides a comprehensive overview of Water's identifiers across various biological and chemical databases.
# ----
#
#
# Query: Find identifiers for COVID-19
#
# ----
# ----
# It seems that there was an issue retrieving identifiers for **COVID-19**. This could be due to the term being too broad or not recognized as a specific compound or gene in the databases I queried.
#
# If you are looking for specific information related to COVID-19, such as identifiers for the virus (SARS-CoV-2), vaccines, or treatments, please provide more details, and I'll be happy to assist!
# ----
#
#
# Query: Map ENSG00000139618 to PubChem
#
# ----
# ----
# The Ensembl gene ID **ENSG00000139618** (which corresponds to the gene **BRCA2**) does not have a direct mapping to a PubChem ID, as PubChem primarily contains information about chemical compounds rather than genes.
#
# However, BRCA2 is associated with certain drugs, particularly in the context of cancer treatment, as mentioned earlier. If you are looking for specific drugs related to BRCA2 or any other information, please let me know!
# ----

# %% [markdown]
# ## 6. Additional Utility Functions
#
# Here are some additional functions to work with the BridgeDB API directly.

# %%
import requests
import pandas as pd

def map_identifier_to_df(species, source_ds, identifier):
    url = f"https://webservice.bridgedb.org/{species}/xrefs/{source_ds}/{identifier}"
    response = requests.get(url)
    if response.status_code != 200:
        return pd.DataFrame({'Error': [f"Failed with status code {response.status_code}"]})

    # Parsing the response
    rows = [line.split('\t') for line in response.text.split('\n') if line]
    df = pd.DataFrame(rows, columns=['Mapped Identifier', 'Target Database'])
    df['Original Identifier'] = identifier
    df['Source Database'] = source_ds
    
    # Reordering columns
    return df[['Original Identifier', 'Source Database', 'Mapped Identifier', 'Target Database']]

# Example usage
result_df = map_identifier_to_df("Homo sapiens", "Cpc", "186907")
result_df
# Out:
#    Original Identifier Source Database            Mapped Identifier  \
# 0               186907             Cpc                    C00000546
# 1               186907             Cpc                   CHEBI:2504
# 2               186907             Cpc                       C06800
# 3               186907             Cpc               DTXSID00873175
# 4               186907             Cpc                       186907
# 5               186907             Cpc  OQIQSTLJSLGHID-WNWIJWBNSA-N
# 6               186907             Cpc                CHEMBL1697694
# 7               186907             Cpc                DTXSID9020035
# 8               186907             Cpc                    1162-65-8
# 9               186907             Cpc                       162470
# 10              186907             Cpc                     Q4689278
# 11              186907             Cpc                  HMDB0006552
# 12              186907             Cpc                         2504
# 13              186907             Cpc                    HMDB06552
#
#      Target Database
# 0           KNApSAcK
# 1              ChEBI
# 2      KEGG Compound
# 3        EPA CompTox
# 4   PubChem-compound
# 5           InChIKey
# 6    ChEMBL compound
# 7        EPA CompTox
# 8                CAS
# 9         Chemspider
# 10          Wikidata
# 11              HMDB
# 12             ChEBI
# 13              HMDB

# %%
import requests
import pandas as pd

def map_batch_identifiers(species, source_ds, identifiers):
    url = f"https://webservice.bridgedb.org/{species}/xrefsBatch/{source_ds}"
    response = requests.post(url, data='\n'.join(identifiers))
    if response.status_code != 200:
        return pd.DataFrame({'Error': [f"Failed with status code {response.status_code}"]})

    # Parsing the response
    records = []
    for line in response.text.strip().split('\n'):
        if line:
            parts = line.split('\t', 1)
            if len(parts) == 2:
                original_id, mappings = parts
                for mapping in mappings.split(','):
                    if ':' in mapping:
                        target_db, mapped_id = mapping.split(':', 1)
                        records.append((original_id, source_ds, mapped_id, target_db))
                    else:
                        records.append((original_id, source_ds, 'Parsing Error', mapping))
            else:
                records.append((line, source_ds, 'Parsing Error', ''))

    df = pd.DataFrame(records, columns=['Original Identifier', 'Source Database', 'Mapped Identifier', 'Target Database'])
    
    if df.empty:
        return "No mappings found for the provided identifiers."
    
    return df

# Example usage
batch_result_df = map_batch_identifiers("Homo sapiens", "H", ["A1BG", "A1CF", "A2MP1"])
batch_result_df
# Out:
#     Original Identifier Source Database Mapped Identifier Target Database
# 0                  A1BG               H           3872844         HGNC\tX
# 1                  A1BG               H           3872845               X
# 2                  A1BG               H           3872842               X
# 3                  A1BG               H           8039748               X
# 4                  A1BG               H            HGNC:5             Hac
# ..                  ...             ...               ...             ...
# 241               A2MP1               H           3443560               X
# 242               A2MP1               H           3443561               X
# 243               A2MP1               H     A_21_P0000904              Ag
# 244               A2MP1               H           3443562               X
# 245               A2MP1               H            HGNC:8             Hac
#
# [246 rows x 4 columns]

# %%
import requests
import pandas as pd

def get_supported_data_sources(species):
    url = f"https://webservice.bridgedb.org/{species}/sourceDataSources"
    response = requests.get(url)
    if response.status_code != 200:
        return pd.DataFrame({'Error': [f"Failed with status code {response.status_code}"]})

    # Parsing the response
    sources = response.text.split('\n')
    df = pd.DataFrame({'Source Databases': sources})
    return df

# Example usage
supported_sources_df = get_supported_data_sources("Homo sapiens")
supported_sources_df
# Out:
#                  Source Databases
# 0                            Rfam
# 1           Guide to Pharmacology
# 2                            Rhea
# 3                           ChEBI
# 4                            HGNC
# 5                         Ensembl
# 6                        Wikidata
# 7                  PubMed Central
# 8                        Illumina
# 9                       KEGG Drug
# 10                            DOI
# 11                  KEGG Compound
# 12                    SwissLipids
# 13                       KNApSAcK
# 14                      WikiGenes
# 15            Enzyme Nomenclature
# 16                        MetaCyc
# 17          HGNC Accession number
# 18                  KEGG Reaction
# 19                          MACiE
# 20                           HMDB
# 21                     Chemspider
# 22                            CAS
# 23               miRBase Sequence
# 24                    Entrez Gene
# 25                         EcoCyc
# 26                        Agilent
# 27                           OMIM
# 28               PubChem-compound
# 29                       Reactome
# 30                            PDB
# 31            UCSC Genome Browser
# 32                           Affy
# 33                ChEMBL compound
# 34                 Uniprot-TrEMBL
# 35                       InChIKey
# 36                 Complex Portal
# 37                         RefSeq
# 38                     LIPID MAPS
# 39                       DrugBank
# 40  Guide to Pharmacology Targets
# 41                         PubMed
# 42                   WikiPathways
# 43                   GeneOntology
# 44                    EPA CompTox
# 45

# %%
import requests

# Example for Busulfan
busulfan_url = "https://bridgedb.cloud.vhp4safety.nl/Human/xrefs/Cpc/2478"
response = requests.get(busulfan_url)

if response.status_code == 200:
    print("Busulfan Mappings:")
    print(response.text)
else:
    print("Failed to retrieve Busulfan mappings:", response.status_code)

# Example for Aflatoxin B1
aflatoxin_url = "https://bridgedb.cloud.vhp4safety.nl/Human/xrefs/Cpc/186907"
response = requests.get(aflatoxin_url)

if response.status_code == 200:
    print("Aflatoxin B1 Mappings:")
    print(response.text)
else:
    print("Failed to retrieve Aflatoxin B1 mappings:", response.status_code)
# Out:
# Busulfan Mappings:
# 2384	Chemspider
# DTXSID3020910	EPA CompTox
# HMDB15143	HMDB
# 28901	ChEBI
# 2478	PubChem-compound
# Q348922	Wikidata
# 55-98-1	CAS
# DB01008	DrugBank
# CHEBI:28901	ChEBI
# 7136	Guide to Pharmacology
# D00248	KEGG Drug
# COVZYZSDYWQREU-UHFFFAOYSA-N	InChIKey
# HMDB0015143	HMDB
# CHEMBL820	ChEMBL compound
# C06862	KEGG Compound
#
# Aflatoxin B1 Mappings:
# C00000546	KNApSAcK
# CHEBI:2504	ChEBI
# C06800	KEGG Compound
# DTXSID00873175	EPA CompTox
# 186907	PubChem-compound
# OQIQSTLJSLGHID-WNWIJWBNSA-N	InChIKey
# CHEMBL1697694	ChEMBL compound
# DTXSID9020035	EPA CompTox
# 1162-65-8	CAS
# 162470	Chemspider
# Q4689278	Wikidata
# HMDB0006552	HMDB
# 2504	ChEBI
# HMDB06552	HMDB
